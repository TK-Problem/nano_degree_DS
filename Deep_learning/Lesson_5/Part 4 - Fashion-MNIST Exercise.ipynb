# %% [markdown]
# # Classifying Fashion-MNIST
#
# Now it's your turn to build and train a neural network. You'll be using the [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist), a drop-in replacement for the MNIST dataset. MNIST is actually quite trivial with neural networks where you can easily achieve better than 97% accuracy. Fashion-MNIST is a set of 28x28 greyscale images of clothes. It's more complex than MNIST, so it's a better representation of the actual performance of your network, and a better representation of datasets you'll use in the real world.
#
# <img src='assets/fashion-mnist-sprite.png' width=500px>
#
# In this notebook, you'll build your own neural network. For the most part, you could just copy and paste the code from Part 3, but you wouldn't be learning. It's important for you to write the code yourself and get it to work. Feel free to consult the previous notebook though as you work through this.
#
# First off, let's load the dataset through torchvision.

# %%
import torch
from torchvision import datasets, transforms
import helper

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# Download and load the training data
trainset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here we can see one of the images.

# %%
image, label = next(iter(trainloader))
helper.imshow(image[0,:]);

# %% [markdown]
# With the data loaded, it's time to import the necessary packages.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

import helper

# %% [markdown]
# ## Building the network
#
# Here you should define your network. As with MNIST, each image is 28x28 which is a total of 784 pixels, and there are 10 classes. You should include at least one hidden layer. We suggest you use ReLU activations for the layers and to return the logits from the forward pass. It's up to you how many layers you add and the size of those layers.

# %%
# Define your network architecture here

# Hyperparameters for our network
input_size = 784
hidden_sizes = [256, 128, 64]
output_size = 10

# Build a feed-forward network
model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], hidden_sizes[2]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[2], output_size),
                      nn.Softmax(dim=1))
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=10, bias=True)
#   (7): Softmax()
# )

# %% [markdown]
# # Train the network
#
# Now you should create your network and train it. First you'll want to define [the criterion](http://pytorch.org/docs/master/nn.html#loss-functions) ( something like `nn.CrossEntropyLoss`) and [the optimizer](http://pytorch.org/docs/master/optim.html) (typically `optim.SGD` or `optim.Adam`).
#
# Then write the training code. Remember the training pass is a fairly straightforward process:
#
# * Make a forward pass through the network to get the logits
# * Use the logits to calculate the loss
# * Perform a backward pass through the network with `loss.backward()` to calculate the gradients
# * Take a step with the optimizer to update the weights
#
# By adjusting the hyperparameters (hidden units, learning rate, etc), you should be able to get the training loss below 0.4.

# %%
# Create the network, define the criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003)

# %%
# Train the network here
epochs = 50
print_every = 100
steps = 0
for e in range(epochs):
    running_loss = 0
    for images, labels in iter(trainloader):
        steps += 1
        # Flatten MNIST images into a 784 long vector
        images.resize_(images.size()[0], 784)
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            print("Epoch: {}/{}... ".format(e+1, epochs),
                  "Loss: {:.4f}".format(running_loss/print_every))
            
            running_loss = 0
# Out:
# Epoch: 1/50...  Loss: 1.9374
# Epoch: 1/50...  Loss: 1.9364
# Epoch: 1/50...  Loss: 1.9273
# Epoch: 1/50...  Loss: 1.9130
# Epoch: 1/50...  Loss: 1.9110
# Epoch: 1/50...  Loss: 1.8982
# Epoch: 1/50...  Loss: 1.8892
# Epoch: 1/50...  Loss: 1.8795
# Epoch: 1/50...  Loss: 1.8768
# Epoch: 2/50...  Loss: 1.1583
# Epoch: 2/50...  Loss: 1.8584
# Epoch: 2/50...  Loss: 1.8634
# Epoch: 2/50...  Loss: 1.8505
# Epoch: 2/50...  Loss: 1.8549
# Epoch: 2/50...  Loss: 1.8505
# Epoch: 2/50...  Loss: 1.8493
# Epoch: 2/50...  Loss: 1.8354
# Epoch: 2/50...  Loss: 1.8320
# Epoch: 3/50...  Loss: 0.4367
# Epoch: 3/50...  Loss: 1.8238
# Epoch: 3/50...  Loss: 1.8250
# Epoch: 3/50...  Loss: 1.8242
# Epoch: 3/50...  Loss: 1.8175
# Epoch: 3/50...  Loss: 1.8094
# Epoch: 3/50...  Loss: 1.8082
# Epoch: 3/50...  Loss: 1.8152
# Epoch: 3/50...  Loss: 1.7971
# Epoch: 3/50...  Loss: 1.8126
# Epoch: 4/50...  Loss: 1.5451
# Epoch: 4/50...  Loss: 1.7953
# Epoch: 4/50...  Loss: 1.8028
# Epoch: 4/50...  Loss: 1.8010
# Epoch: 4/50...  Loss: 1.8045
# Epoch: 4/50...  Loss: 1.7986
# Epoch: 4/50...  Loss: 1.7911
# Epoch: 4/50...  Loss: 1.7887
# Epoch: 4/50...  Loss: 1.7934
# Epoch: 5/50...  Loss: 0.8596
# Epoch: 5/50...  Loss: 1.7992
# Epoch: 5/50...  Loss: 1.7909
# Epoch: 5/50...  Loss: 1.7855
# Epoch: 5/50...  Loss: 1.7837
# Epoch: 5/50...  Loss: 1.7876
# Epoch: 5/50...  Loss: 1.7840
# Epoch: 5/50...  Loss: 1.7842
# Epoch: 5/50...  Loss: 1.7799
# Epoch: 6/50...  Loss: 0.1778
# Epoch: 6/50...  Loss: 1.7844
# Epoch: 6/50...  Loss: 1.7853
# Epoch: 6/50...  Loss: 1.7770
# Epoch: 6/50...  Loss: 1.7801
# Epoch: 6/50...  Loss: 1.7755
# Epoch: 6/50...  Loss: 1.7772
# Epoch: 6/50...  Loss: 1.7801
# Epoch: 6/50...  Loss: 1.7741
# Epoch: 6/50...  Loss: 1.7826
# Epoch: 7/50...  Loss: 1.2783
# Epoch: 7/50...  Loss: 1.7765
# Epoch: 7/50...  Loss: 1.7665
# Epoch: 7/50...  Loss: 1.7662
# Epoch: 7/50...  Loss: 1.7760
# Epoch: 7/50...  Loss: 1.7822
# Epoch: 7/50...  Loss: 1.7888
# Epoch: 7/50...  Loss: 1.7721
# Epoch: 7/50...  Loss: 1.7629
# Epoch: 8/50...  Loss: 0.6020
# Epoch: 8/50...  Loss: 1.7782
# Epoch: 8/50...  Loss: 1.7659
# Epoch: 8/50...  Loss: 1.7602
# Epoch: 8/50...  Loss: 1.7773
# Epoch: 8/50...  Loss: 1.7652
# Epoch: 8/50...  Loss: 1.7759
# Epoch: 8/50...  Loss: 1.7656
# Epoch: 8/50...  Loss: 1.7691
# Epoch: 8/50...  Loss: 1.7782
# Epoch: 9/50...  Loss: 1.6963
# Epoch: 9/50...  Loss: 1.7800
# Epoch: 9/50...  Loss: 1.7614
# Epoch: 9/50...  Loss: 1.7695
# Epoch: 9/50...  Loss: 1.7716
# Epoch: 9/50...  Loss: 1.7631
# Epoch: 9/50...  Loss: 1.7640
# Epoch: 9/50...  Loss: 1.7621
# Epoch: 9/50...  Loss: 1.7642
# Epoch: 10/50...  Loss: 1.0184
# Epoch: 10/50...  Loss: 1.7652
# Epoch: 10/50...  Loss: 1.7768
# Epoch: 10/50...  Loss: 1.7699
# Epoch: 10/50...  Loss: 1.7637
# Epoch: 10/50...  Loss: 1.7627
# Epoch: 10/50...  Loss: 1.7638
# Epoch: 10/50...  Loss: 1.7650
# Epoch: 10/50...  Loss: 1.7519
# Epoch: 11/50...  Loss: 0.3511
# Epoch: 11/50...  Loss: 1.7670
# Epoch: 11/50...  Loss: 1.7621
# Epoch: 11/50...  Loss: 1.7623
# Epoch: 11/50...  Loss: 1.7581
# Epoch: 11/50...  Loss: 1.7618
# Epoch: 11/50...  Loss: 1.7572
# Epoch: 11/50...  Loss: 1.7628
# Epoch: 11/50...  Loss: 1.7523
# Epoch: 11/50...  Loss: 1.7636
# Epoch: 12/50...  Loss: 1.4505
# Epoch: 12/50...  Loss: 1.7589
# Epoch: 12/50...  Loss: 1.7551
# Epoch: 12/50...  Loss: 1.7566
# Epoch: 12/50...  Loss: 1.7578
# Epoch: 12/50...  Loss: 1.7607
# Epoch: 12/50...  Loss: 1.7529
# Epoch: 12/50...  Loss: 1.7622
# Epoch: 12/50...  Loss: 1.7543
# Epoch: 13/50...  Loss: 0.7723
# Epoch: 13/50...  Loss: 1.7600
# Epoch: 13/50...  Loss: 1.7567
# Epoch: 13/50...  Loss: 1.7564
# Epoch: 13/50...  Loss: 1.7546
# Epoch: 13/50...  Loss: 1.7600
# Epoch: 13/50...  Loss: 1.7658
# Epoch: 13/50...  Loss: 1.7459
# Epoch: 13/50...  Loss: 1.7558
# Epoch: 14/50...  Loss: 0.1066
# Epoch: 14/50...  Loss: 1.7592
# Epoch: 14/50...  Loss: 1.7441
# Epoch: 14/50...  Loss: 1.7584
# Epoch: 14/50...  Loss: 1.7573
# Epoch: 14/50...  Loss: 1.7531
# Epoch: 14/50...  Loss: 1.7517
# Epoch: 14/50...  Loss: 1.7557
# Epoch: 14/50...  Loss: 1.7541
# Epoch: 14/50...  Loss: 1.7521
# Epoch: 15/50...  Loss: 1.1913
# Epoch: 15/50...  Loss: 1.7483
# Epoch: 15/50...  Loss: 1.7484
# Epoch: 15/50...  Loss: 1.7555
# Epoch: 15/50...  Loss: 1.7587
# Epoch: 15/50...  Loss: 1.7510
# Epoch: 15/50...  Loss: 1.7493
# Epoch: 15/50...  Loss: 1.7540
# Epoch: 15/50...  Loss: 1.7445
# Epoch: 16/50...  Loss: 0.5241
# Epoch: 16/50...  Loss: 1.7495
# Epoch: 16/50...  Loss: 1.7539
# Epoch: 16/50...  Loss: 1.7532
# Epoch: 16/50...  Loss: 1.7433
# Epoch: 16/50...  Loss: 1.7535
# Epoch: 16/50...  Loss: 1.7445
# Epoch: 16/50...  Loss: 1.7483
# Epoch: 16/50...  Loss: 1.7464
# Epoch: 16/50...  Loss: 1.7525
# Epoch: 17/50...  Loss: 1.6056
# Epoch: 17/50...  Loss: 1.7413
# Epoch: 17/50...  Loss: 1.7539
# Epoch: 17/50...  Loss: 1.7449
# Epoch: 17/50...  Loss: 1.7432
# Epoch: 17/50...  Loss: 1.7496
# Epoch: 17/50...  Loss: 1.7531
# Epoch: 17/50...  Loss: 1.7495
# Epoch: 17/50...  Loss: 1.7472
# Epoch: 18/50...  Loss: 0.9403
# Epoch: 18/50...  Loss: 1.7492
# Epoch: 18/50...  Loss: 1.7436
# Epoch: 18/50...  Loss: 1.7567
# Epoch: 18/50...  Loss: 1.7401
# Epoch: 18/50...  Loss: 1.7437
# Epoch: 18/50...  Loss: 1.7466
# Epoch: 18/50...  Loss: 1.7365
# Epoch: 18/50...  Loss: 1.7482
# Epoch: 19/50...  Loss: 0.2792
# Epoch: 19/50...  Loss: 1.7397
# Epoch: 19/50...  Loss: 1.7371
# Epoch: 19/50...  Loss: 1.7420
# Epoch: 19/50...  Loss: 1.7505
# Epoch: 19/50...  Loss: 1.7467
# Epoch: 19/50...  Loss: 1.7452
# Epoch: 19/50...  Loss: 1.7407
# Epoch: 19/50...  Loss: 1.7509
# Epoch: 19/50...  Loss: 1.7447
# Epoch: 20/50...  Loss: 1.3571
# Epoch: 20/50...  Loss: 1.7496
# Epoch: 20/50...  Loss: 1.7408
# Epoch: 20/50...  Loss: 1.7400
# Epoch: 20/50...  Loss: 1.7475
# Epoch: 20/50...  Loss: 1.7443
# Epoch: 20/50...  Loss: 1.7392
# Epoch: 20/50...  Loss: 1.7397
# Epoch: 20/50...  Loss: 1.7462
# Epoch: 21/50...  Loss: 0.6904
# Epoch: 21/50...  Loss: 1.7445
# Epoch: 21/50...  Loss: 1.7423
# Epoch: 21/50...  Loss: 1.7436
# Epoch: 21/50...  Loss: 1.7452
# Epoch: 21/50...  Loss: 1.7435
# Epoch: 21/50...  Loss: 1.7396
# Epoch: 21/50...  Loss: 1.7350
# Epoch: 21/50...  Loss: 1.7404
# Epoch: 22/50...  Loss: 0.0350
# Epoch: 22/50...  Loss: 1.7399
# Epoch: 22/50...  Loss: 1.7348
# Epoch: 22/50...  Loss: 1.7383
# Epoch: 22/50...  Loss: 1.7410
# Epoch: 22/50...  Loss: 1.7448
# Epoch: 22/50...  Loss: 1.7411
# Epoch: 22/50...  Loss: 1.7418
# Epoch: 22/50...  Loss: 1.7359
# Epoch: 22/50...  Loss: 1.7337
# Epoch: 23/50...  Loss: 1.1121
# Epoch: 23/50...  Loss: 1.7350
# Epoch: 23/50...  Loss: 1.7411
# Epoch: 23/50...  Loss: 1.7419
# Epoch: 23/50...  Loss: 1.7244
# Epoch: 23/50...  Loss: 1.7387
# Epoch: 23/50...  Loss: 1.7467
# Epoch: 23/50...  Loss: 1.7474
# Epoch: 23/50...  Loss: 1.7324
# Epoch: 24/50...  Loss: 0.4526
# Epoch: 24/50...  Loss: 1.7411
# Epoch: 24/50...  Loss: 1.7393
# Epoch: 24/50...  Loss: 1.7379
# Epoch: 24/50...  Loss: 1.7456
# Epoch: 24/50...  Loss: 1.7406
# Epoch: 24/50...  Loss: 1.7337
# Epoch: 24/50...  Loss: 1.7358
# Epoch: 24/50...  Loss: 1.7346
# Epoch: 24/50...  Loss: 1.7249
# Epoch: 25/50...  Loss: 1.5313
# Epoch: 25/50...  Loss: 1.7368
# Epoch: 25/50...  Loss: 1.7292
# Epoch: 25/50...  Loss: 1.7427
# Epoch: 25/50...  Loss: 1.7436
# Epoch: 25/50...  Loss: 1.7414
# Epoch: 25/50...  Loss: 1.7275
# Epoch: 25/50...  Loss: 1.7293
# Epoch: 25/50...  Loss: 1.7395
# Epoch: 26/50...  Loss: 0.8670
# Epoch: 26/50...  Loss: 1.7362
# Epoch: 26/50...  Loss: 1.7377
# Epoch: 26/50...  Loss: 1.7321
# Epoch: 26/50...  Loss: 1.7373
# Epoch: 26/50...  Loss: 1.7318
# Epoch: 26/50...  Loss: 1.7405
# Epoch: 26/50...  Loss: 1.7364
# Epoch: 26/50...  Loss: 1.7271
# Epoch: 27/50...  Loss: 0.2070
# Epoch: 27/50...  Loss: 1.7333
# Epoch: 27/50...  Loss: 1.7409
# Epoch: 27/50...  Loss: 1.7386
# Epoch: 27/50...  Loss: 1.7244
# Epoch: 27/50...  Loss: 1.7410
# Epoch: 27/50...  Loss: 1.7398
# Epoch: 27/50...  Loss: 1.7277
# Epoch: 27/50...  Loss: 1.7264
# Epoch: 27/50...  Loss: 1.7378
# Epoch: 28/50...  Loss: 1.2798
# Epoch: 28/50...  Loss: 1.7326
# Epoch: 28/50...  Loss: 1.7300
# Epoch: 28/50...  Loss: 1.7315
# Epoch: 28/50...  Loss: 1.7363
# Epoch: 28/50...  Loss: 1.7403
# Epoch: 28/50...  Loss: 1.7307
# Epoch: 28/50...  Loss: 1.7285
# Epoch: 28/50...  Loss: 1.7389
# Epoch: 29/50...  Loss: 0.6256
# Epoch: 29/50...  Loss: 1.7308
# Epoch: 29/50...  Loss: 1.7397
# Epoch: 29/50...  Loss: 1.7294
# Epoch: 29/50...  Loss: 1.7314
# Epoch: 29/50...  Loss: 1.7383
# Epoch: 29/50...  Loss: 1.7303
# Epoch: 29/50...  Loss: 1.7279
# Epoch: 29/50...  Loss: 1.7337
# Epoch: 29/50...  Loss: 1.7292
# Epoch: 30/50...  Loss: 1.6970
# Epoch: 30/50...  Loss: 1.7310
# Epoch: 30/50...  Loss: 1.7297
# Epoch: 30/50...  Loss: 1.7301
# Epoch: 30/50...  Loss: 1.7364
# Epoch: 30/50...  Loss: 1.7370
# Epoch: 30/50...  Loss: 1.7242
# Epoch: 30/50...  Loss: 1.7232
# Epoch: 30/50...  Loss: 1.7369
# Epoch: 31/50...  Loss: 1.0389
# Epoch: 31/50...  Loss: 1.7302
# Epoch: 31/50...  Loss: 1.7326
# Epoch: 31/50...  Loss: 1.7314
# Epoch: 31/50...  Loss: 1.7327
# Epoch: 31/50...  Loss: 1.7324
# Epoch: 31/50...  Loss: 1.7379
# Epoch: 31/50...  Loss: 1.7252
# Epoch: 31/50...  Loss: 1.7236
# Epoch: 32/50...  Loss: 0.3814
# Epoch: 32/50...  Loss: 1.7227
# Epoch: 32/50...  Loss: 1.7281
# Epoch: 32/50...  Loss: 1.7378
# Epoch: 32/50...  Loss: 1.7357
# Epoch: 32/50...  Loss: 1.7248
# Epoch: 32/50...  Loss: 1.7312
# Epoch: 32/50...  Loss: 1.7291
# Epoch: 32/50...  Loss: 1.7331
# Epoch: 32/50...  Loss: 1.7308
# Epoch: 33/50...  Loss: 1.4579
# Epoch: 33/50...  Loss: 1.7273
# Epoch: 33/50...  Loss: 1.7232
# Epoch: 33/50...  Loss: 1.7288
# Epoch: 33/50...  Loss: 1.7380
# Epoch: 33/50...  Loss: 1.7331
# Epoch: 33/50...  Loss: 1.7281
# Epoch: 33/50...  Loss: 1.7292
# Epoch: 33/50...  Loss: 1.7252
# Epoch: 34/50...  Loss: 0.7986
# Epoch: 34/50...  Loss: 1.7315
# Epoch: 34/50...  Loss: 1.7287
# Epoch: 34/50...  Loss: 1.7298
# Epoch: 34/50...  Loss: 1.7303
# Epoch: 34/50...  Loss: 1.7243
# Epoch: 34/50...  Loss: 1.7304
# Epoch: 34/50...  Loss: 1.7215
# Epoch: 34/50...  Loss: 1.7305
# Epoch: 35/50...  Loss: 0.1376
# Epoch: 35/50...  Loss: 1.7250
# Epoch: 35/50...  Loss: 1.7319
# Epoch: 35/50...  Loss: 1.7281
# Epoch: 35/50...  Loss: 1.7303
# Epoch: 35/50...  Loss: 1.7289
# Epoch: 35/50...  Loss: 1.7314
# Epoch: 35/50...  Loss: 1.7286
# Epoch: 35/50...  Loss: 1.7272
# Epoch: 35/50...  Loss: 1.7186
# Epoch: 36/50...  Loss: 1.2053
# Epoch: 36/50...  Loss: 1.7277
# Epoch: 36/50...  Loss: 1.7296
# Epoch: 36/50...  Loss: 1.7211
# Epoch: 36/50...  Loss: 1.7357
# Epoch: 36/50...  Loss: 1.7307
# Epoch: 36/50...  Loss: 1.7203
# Epoch: 36/50...  Loss: 1.7351
# Epoch: 36/50...  Loss: 1.7295
# Epoch: 37/50...  Loss: 0.5521
# Epoch: 37/50...  Loss: 1.7180
# Epoch: 37/50...  Loss: 1.7175
# Epoch: 37/50...  Loss: 1.7377
# Epoch: 37/50...  Loss: 1.7269
# Epoch: 37/50...  Loss: 1.7269
# Epoch: 37/50...  Loss: 1.7268
# Epoch: 37/50...  Loss: 1.7245
# Epoch: 37/50...  Loss: 1.7261
# Epoch: 37/50...  Loss: 1.7389
# Epoch: 38/50...  Loss: 1.6260
# Epoch: 38/50...  Loss: 1.7209
# Epoch: 38/50...  Loss: 1.7285
# Epoch: 38/50...  Loss: 1.7272
# Epoch: 38/50...  Loss: 1.7321
# Epoch: 38/50...  Loss: 1.7325
# Epoch: 38/50...  Loss: 1.7344
# Epoch: 38/50...  Loss: 1.7131
# Epoch: 38/50...  Loss: 1.7200
# Epoch: 39/50...  Loss: 0.9701
# Epoch: 39/50...  Loss: 1.7329
# Epoch: 39/50...  Loss: 1.7276
# Epoch: 39/50...  Loss: 1.7257
# Epoch: 39/50...  Loss: 1.7261
# Epoch: 39/50...  Loss: 1.7223
# Epoch: 39/50...  Loss: 1.7254
# Epoch: 39/50...  Loss: 1.7226
# Epoch: 39/50...  Loss: 1.7180
# Epoch: 40/50...  Loss: 0.3117
# Epoch: 40/50...  Loss: 1.7182
# Epoch: 40/50...  Loss: 1.7290
# Epoch: 40/50...  Loss: 1.7240
# Epoch: 40/50...  Loss: 1.7268
# Epoch: 40/50...  Loss: 1.7272
# Epoch: 40/50...  Loss: 1.7326
# Epoch: 40/50...  Loss: 1.7285
# Epoch: 40/50...  Loss: 1.7170
# Epoch: 40/50...  Loss: 1.7224
# Epoch: 41/50...  Loss: 1.3753
# Epoch: 41/50...  Loss: 1.7264
# Epoch: 41/50...  Loss: 1.7230
# Epoch: 41/50...  Loss: 1.7147
# Epoch: 41/50...  Loss: 1.7298
# Epoch: 41/50...  Loss: 1.7191
# Epoch: 41/50...  Loss: 1.7251
# Epoch: 41/50...  Loss: 1.7329
# Epoch: 41/50...  Loss: 1.7316
# Epoch: 42/50...  Loss: 0.7284
# Epoch: 42/50...  Loss: 1.7199
# Epoch: 42/50...  Loss: 1.7274
# Epoch: 42/50...  Loss: 1.7229
# Epoch: 42/50...  Loss: 1.7187
# Epoch: 42/50...  Loss: 1.7173
# Epoch: 42/50...  Loss: 1.7300
# Epoch: 42/50...  Loss: 1.7255
# Epoch: 42/50...  Loss: 1.7257
# Epoch: 43/50...  Loss: 0.0678
# Epoch: 43/50...  Loss: 1.7183
# Epoch: 43/50...  Loss: 1.7203
# Epoch: 43/50...  Loss: 1.7246
# Epoch: 43/50...  Loss: 1.7301
# Epoch: 43/50...  Loss: 1.7287
# Epoch: 43/50...  Loss: 1.7203
# Epoch: 43/50...  Loss: 1.7221
# Epoch: 43/50...  Loss: 1.7200
# Epoch: 43/50...  Loss: 1.7276
# Epoch: 44/50...  Loss: 1.1427
# Epoch: 44/50...  Loss: 1.7198
# Epoch: 44/50...  Loss: 1.7200
# Epoch: 44/50...  Loss: 1.7216
# Epoch: 44/50...  Loss: 1.7267
# Epoch: 44/50...  Loss: 1.7245
# Epoch: 44/50...  Loss: 1.7193
# Epoch: 44/50...  Loss: 1.7244
# Epoch: 44/50...  Loss: 1.7243
# Epoch: 45/50...  Loss: 0.4807
# Epoch: 45/50...  Loss: 1.7285
# Epoch: 45/50...  Loss: 1.7154
# Epoch: 45/50...  Loss: 1.7326
# Epoch: 45/50...  Loss: 1.7227
# Epoch: 45/50...  Loss: 1.7280
# Epoch: 45/50...  Loss: 1.7209
# Epoch: 45/50...  Loss: 1.7190
# Epoch: 45/50...  Loss: 1.7186
# Epoch: 45/50...  Loss: 1.7204
# Epoch: 46/50...  Loss: 1.5509
# Epoch: 46/50...  Loss: 1.7278
# Epoch: 46/50...  Loss: 1.7208
# Epoch: 46/50...  Loss: 1.7269
# Epoch: 46/50...  Loss: 1.7264
# Epoch: 46/50...  Loss: 1.7223
# Epoch: 46/50...  Loss: 1.7240
# Epoch: 46/50...  Loss: 1.7166
# Epoch: 46/50...  Loss: 1.7206
# Epoch: 47/50...  Loss: 0.8955
# Epoch: 47/50...  Loss: 1.7188
# Epoch: 47/50...  Loss: 1.7171
# Epoch: 47/50...  Loss: 1.7143
# Epoch: 47/50...  Loss: 1.7202
# Epoch: 47/50...  Loss: 1.7260
# Epoch: 47/50...  Loss: 1.7186
# Epoch: 47/50...  Loss: 1.7257
# Epoch: 47/50...  Loss: 1.7234
# Epoch: 48/50...  Loss: 0.2444
# Epoch: 48/50...  Loss: 1.7169
# Epoch: 48/50...  Loss: 1.7219
# Epoch: 48/50...  Loss: 1.7171
# Epoch: 48/50...  Loss: 1.7232
# Epoch: 48/50...  Loss: 1.7201
# Epoch: 48/50...  Loss: 1.7221
# Epoch: 48/50...  Loss: 1.7277
# Epoch: 48/50...  Loss: 1.7202
# Epoch: 48/50...  Loss: 1.7211
# Epoch: 49/50...  Loss: 1.3028
# Epoch: 49/50...  Loss: 1.7183
# Epoch: 49/50...  Loss: 1.7205
# Epoch: 49/50...  Loss: 1.7189
# Epoch: 49/50...  Loss: 1.7297
# Epoch: 49/50...  Loss: 1.7203
# Epoch: 49/50...  Loss: 1.7224
# Epoch: 49/50...  Loss: 1.7187
# Epoch: 49/50...  Loss: 1.7227
# Epoch: 50/50...  Loss: 0.6527
# Epoch: 50/50...  Loss: 1.7317
# Epoch: 50/50...  Loss: 1.7183
# Epoch: 50/50...  Loss: 1.7247
# Epoch: 50/50...  Loss: 1.7257
# Epoch: 50/50...  Loss: 1.7117
# Epoch: 50/50...  Loss: 1.7239
# Epoch: 50/50...  Loss: 1.7157
# Epoch: 50/50...  Loss: 1.7192
# Epoch: 50/50...  Loss: 1.7150

# %%
# Test out your network!

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.resize_(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    logits = model.forward(img)
    
ps = F.softmax(logits, dim=1)

# Plot the image and probabilities
helper.view_classify(img.resize_(1, 28, 28), ps, version='Fashion')

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.resize_(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    logits = model.forward(img)
    
ps = F.softmax(logits, dim=1)

# Plot the image and probabilities
helper.view_classify(img.resize_(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# Now that your network is trained, you'll want to save it to disk so you can load it later instead of training it again. Obviously, it's impractical to train a network every time you need one. In practice, you'll train it once, save the model, then reload it for further training or making predictions. In the next part, I'll show you how to save and load trained models.
