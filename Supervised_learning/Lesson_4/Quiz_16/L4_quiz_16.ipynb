# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("ml-bugs.csv")

# %%
sns.catplot(x="Species", y="Length (mm)", hue="Color", data=data);

# %%
plt.figure()

# data.plot.bar(y="Species")
# df['colour'].value_counts().plot(kind='bar')
data['Species'].value_counts().plot(kind='bar')

plt.show()

# %%
data['Length (mm)']
# Out:
# 0     11.6
# 1     16.3
# 2     15.1
# 3     23.7
# 4     18.4
# 5     17.1
# 6     15.7
# 7     18.6
# 8     22.9
# 9     21.0
# 10    20.5
# 11    21.2
# 12    13.8
# 13    14.5
# 14    24.8
# 15    18.2
# 16    17.9
# 17    22.7
# 18    19.9
# 19    14.6
# 20    19.2
# 21    14.1
# 22    18.8
# 23    13.1
# Name: Length (mm), dtype: float64
